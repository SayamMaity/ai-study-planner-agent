# %% [markdown]
# # Tests & Unit Checks

# %%
from src.planner_agent import generate_weekly_plan, total_planned_hours
p = generate_weekly_plan(['Python','Math'], 5)
print('Total hours:', total_planned_hours(p))
assert total_planned_hours(p) <= 6
print('Sanity check passed')
